# %%
# !pip install coloredlogs
# Out:
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: pyreadline3, humanfriendly, coloredlogs
#
#    ---------------------------------------- 0/3 [pyreadline3]
#    ---------------------------------------- 0/3 [pyreadline3]
#    ---------------------------------------- 0/3 [pyreadline3]
#    ------------- -------------------------- 1/3 [humanfriendly]
#    ------------- -------------------------- 1/3 [humanfriendly]
#    -------------------------- ------------- 2/3 [coloredlogs]
#    ---------------------------------------- 3/3 [coloredlogs]
#
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 pyreadline3-3.5.4

# %%
import coloredlogs, logging

# Create a logger object.
logger = logging.getLogger(__name__)

# By default the install() function installs a handler on the root logger,
# this means that log messages from your code and log messages from the
# libraries that you use will all show up on the terminal.
coloredlogs.install()

# If you don't want to see log messages from libraries, you can pass a
# specific logger object to the install() function. In this case only log
# messages originating from that logger will show up on the terminal.
coloredlogs.install(level='DEBUG', logger=logger)

# Some examples.
logger.debug("this is a debugging message")
logger.info("this is an informational message")
logger.warning("this is a warning message")
logger.error("this is an error message")
logger.critical("this is a critical message")
# Out:
# 2025-06-24 03:40:31 David __main__[6604] DEBUG this is a debugging message
# 2025-06-24 03:40:31 David __main__[6604] INFO this is an informational message
# 2025-06-24 03:40:31 David __main__[6604] WARNING this is a warning message
# 2025-06-24 03:40:31 David __main__[6604] ERROR this is an error message
# 2025-06-24 03:40:31 David __main__[6604] CRITICAL this is a critical message
